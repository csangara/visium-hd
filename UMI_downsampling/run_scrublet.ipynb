# %%
import scanpy as sc

# %%
adata = sc.read_h5ad("/home/chananchidas/visium-hd/data/MouseBrain_UMI_downsampling/brain_cortex_generation_real_rep2.h5ad")

# %%
sc.pp.scrublet(adata)

# %%
# Get sum of predicted_doublet column
adata.obs['predicted_doublet'].value_counts()
# Out:
# predicted_doublet
# False    13005
# Name: count, dtype: int64

# %%
sc.pp.scrublet(adata, expected_doublet_rate=0.5)

# %%
adata.obs['predicted_doublet'].value_counts()
# Out:
# predicted_doublet
# True     12883
# False      122
# Name: count, dtype: int64

# %%
# Save obs dataframe to csv
adata.obs.to_csv("/home/chananchidas/visium-hd/UMI_downsampling/brain_cortex_generation_real/scrublet_brain_cortex_generation_real_rep2.csv")
